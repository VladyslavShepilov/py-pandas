# %% [markdown]
# # Pandas

# %% [markdown]
# ## Task 1
#
# You should import the necessary libraries. You will use `numpy` and `pandas` libraries.
#
#
# > Don't forget to import `numpy`, and `pandas` in short form.

# %%
import pandas as pd
import numpy as np
from setuptools.dist import sequence

# %% [markdown]
# ## Task 2
#
# Create a `DataFrame` from the given dictionary `data`.

# %%
data = {
    "Name": ["John", "Emily", "Ryan"],
    "Age": [16, 28, 22],
    "City": ["New York", "Los Angeles", "Chicago"],
}

arr = pd.DataFrame(data)

# %% [markdown]
# ## Task 3
#
# In this task you should complete the following steps:

# %% [markdown]
# ### Task 3.1
# Display all data for `Age` column for the DataFrame you created in the previous task.

# %%
age = arr["Age"]
print(age)
# Out:
# 0    16
# 1    28
# 2    22
# Name: Age, dtype: int64

# %% [markdown]
# ### Task 3.2
#
# Add `Salary` column to the `DataFrame` with the values `[50000, 60000, 45000]`.

# %%
arr["Salary"] = [5000, 6000, 45000]
print(arr)
# Out:
#     Name  Age         City  Salary
# 0   John   16     New York    5000
# 1  Emily   28  Los Angeles    6000
# 2   Ryan   22      Chicago   45000

# %% [markdown]
# ### Task 3.3
#
# Filter the `DataFrame` to show only the rows with the `Age` greater than 18.

# %%
gte_18_mask = arr["Age"] >= 18
get_18_dataset = arr[gte_18_mask]
print(get_18_dataset)
# Out:
#     Name  Age         City
# 1  Emily   28  Los Angeles
# 2   Ryan   22      Chicago

# %% [markdown]
# ## Task 4
#
# In this task you should complete the following steps:

# %% [markdown]
# ### Task 4.1
#
# Add new calculated field `Birth year`;

# %%
curr_year = 2025
arr["Birth year"] = curr_year - arr["Age"]
print(arr)
# Out:
#     Name  Age         City  Birth year
# 0   John   16     New York        2009
# 1  Emily   28  Los Angeles        1997
# 2   Ryan   22      Chicago        2003

# %% [markdown]
# ### Task 4.2
#
# Add new calculated field `Average age`.

# %%
arr["Average age"] = arr["Age"].mean()
print(arr)
# Out:
#     Name  Age         City  Birth year  Average age
# 0   John   16     New York        2009         22.0
# 1  Emily   28  Los Angeles        1997         22.0
# 2   Ryan   22      Chicago        2003         22.0

# %% [markdown]
# ### Task 4.3
#
# Calculate absolute difference between `Age` and `Average age`.

# %%
avg_diff = np.abs(arr["Age"]- arr["Average age"])
print(avg_diff)
# Out:
# 0    6.0
# 1    6.0
# 2    0.0
# dtype: float64

# %% [markdown]
# ## Task 5
#
# Complete the following tasks described below.

# %% [markdown]
# ### Task 5.1
#
# You have two dictionaries `data1` and `data2`. Create two `DataFrame` objects from these dictionaries. Then, `concatenate`, and `merge` these two `DataFrame` objects into one `DataFrame` object, and see the difference.

# %%
# Data
data1 = {'Name': ['John', 'Emily', 'Ryan'],
         'Age': [25, 28, 22]}
data2 = {'Name': ['Emily', 'Ryan', 'Mike'],
         'City': ['Los Angeles', 'Chicago', 'Houston']}

df_1 = pd.DataFrame(data1)
df_2 = pd.DataFrame(data2)

# %%
merged = pd.merge(df_1, df_2, on="Name")
print(merged)
# Out:
#     Name  Age         City
# 0  Emily   28  Los Angeles
# 1   Ryan   22      Chicago

# %%
concatenated = pd.concat([df_1, df_2])
print(concatenated)
# Out:
#     Name   Age         City
# 0   John  25.0          NaN
# 1  Emily  28.0          NaN
# 2   Ryan  22.0          NaN
# 0  Emily   NaN  Los Angeles
# 1   Ryan   NaN      Chicago
# 2   Mike   NaN      Houston

# %% [markdown]
# ### Task 5.2
#
# You have two `Series` objects `s1` and `s2`. Make default mathematical operations on these two `Series` objects. Such as `+`, `-`, `*`, `/`, `**`, `//`, `%`. Also, filter `s1` and print only even numbers, and `s2` only with odd numbers.

# %%
s1 = pd.Series([1, 2, 3, 4, 5])
s2 = pd.Series([6, 7, 8, 9, 10])

# %%
total = s1 + s2
print(total)
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64

# %%
subtract = s1 - s2
print(subtract)
# Out:
# 0   -5
# 1   -5
# 2   -5
# 3   -5
# 4   -5
# dtype: int64

# %%
multiply = s1 * s2
print(multiply)
# Out:
# 0     6
# 1    14
# 2    24
# 3    36
# 4    50
# dtype: int64

# %%
divide = s1 / s2
print(divide)
# Out:
# 0    0.166667
# 1    0.285714
# 2    0.375000
# 3    0.444444
# 4    0.500000
# dtype: float64

# %%
squared = s1 ** s2
print(squared)
# Out:
# 0          1
# 1        128
# 2       6561
# 3     262144
# 4    9765625
# dtype: int64

# %%
int_divide = s1 // s2
print(int_divide)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
undivided = s1 % s2
print(undivided)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
odd_s1 = s1[s1 % 2 == 0]
print(odd_s1)
# Out:
# 1    2
# 3    4
# dtype: int64

# %%
even_s2 = s2[s2 % 2 != 0]
print(even_s2)
# Out:
# 1    7
# 3    9
# dtype: int64

# %% [markdown]
# ### Task 5.3
#
# You have a `Serias` object `s`. Make the following operations on this `Series` object:
#
# * make all words in uppercase without loops;
# * get length of each word without loops.

# %%
s = pd.Series(["numpy", "pandas", "matplotlib"])

# %%
s_capitalize = s.str.capitalize()
print(s_capitalize)
# Out:
# 0         Numpy
# 1        Pandas
# 2    Matplotlib
# dtype: object

# %%
s_w_len = s.str.len()
print(s_w_len)
# Out:
# 0     5
# 1     6
# 2    10
# dtype: int64

# %% [markdown]
# ## Task 6 Optional
#
# You have a large dataset consisting of a series of numbers. Your task is to calculate the moving average of the series using a window of `5` elements. The moving average is the average of a set of consecutive values in the series, where the window `slides` through the series to compute the average at each position. The goal is to calculate the moving average efficiently and accurately. Also, compare time performance of Python and Pandas solutions.
#
# > Please, note: If you get `nan` while calculating the moving average, you should remove it from the result. Pandas solution should take 1-2 lines of code.

# %% [markdown]
# ### Python Solution
#
# In the Python solution, a large dataset is generated using random numbers. The moving average is computed by iterating over the dataset using a loop. At each position, a window of 5 elements is created, and the average is calculated by summing the values in the window and dividing by 5.

# %%
import random
sum = __builtins__.sum


def unknown_signature():
    # Generate a large dataset
    data = [random.randint(1, 100) for _ in range(10000000)]

    # Calculate the moving average with a window of 5
    moving_averages = []
    for i in range(4, len(data)):
        window = data[i - 4 : i + 1]
        average = sum(window) / 5
        moving_averages.append(average)
    return moving_averages[:10]

# %time unknown_signature()
# Out:
# CPU times: user 4 s, sys: 70.3 ms, total: 4.07 s
# Wall time: 4.08 s
# [53.2, 38.0, 43.0, 46.0, 41.6, 50.4, 60.4, 62.8, 65.4, 65.4]

# %% [markdown]
# ### Solution using Pandas and Numpy

# %%
def func():
    sequence = np.random.randint(0, 100, 10000000)
    chunk_size = 5

    df = pd.DataFrame({"Values": sequence})
    df["Chunk Number"] = np.arange(len(df)) // chunk_size

    random_sums = df.groupby("Chunk Number")["Values"].sum()
    df = df.merge(random_sums, on="Chunk Number")

    return df

# %time df = func()
print(df.tail(10))
# Out:
# CPU times: user 444 ms, sys: 128 ms, total: 572 ms
# Wall time: 592 ms
#          Values_x  Chunk Number  Values_y
# 9999990        10       1999998       270
# 9999991        67       1999998       270
# 9999992        23       1999998       270
# 9999993        72       1999998       270
# 9999994        98       1999998       270
# 9999995        55       1999999       115
# 9999996         7       1999999       115
# 9999997         2       1999999       115
# 9999998        35       1999999       115
# 9999999        16       1999999       115
